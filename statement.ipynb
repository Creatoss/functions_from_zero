# %% [markdown]
# <a href="https://colab.research.google.com/github/Creatoss/functions_from_zero/blob/main/statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")

# %% [markdown]
# # data structres

# %%
List = [0,1,2]
list[0]
# Out:
# list[0]
